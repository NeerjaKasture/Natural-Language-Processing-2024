# %%
# !pip install requests beautifulsoup4 pandas
# !pip install beautifulsoup4 requests pandas
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4) (2.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.8.30)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %% [markdown]
# **Done**

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

# Function to generate date range from start to end
def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

# Function to extract article URLs, titles, and content from each page
def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

# Generate a range of dates to scrape (change the start and end date as needed)
start_date = "2008-08-01"
end_date = "2010-08-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

# Create a DataFrame from the lists (limit to the first 20 articles)
df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

# Save DataFrame to CSV
df.to_csv('jang_archive_articles_01-08-2008 to 01-08-2010.csv', index=False)
print("Scraping completed - '01-08-2008 to 01-08-2010'")
# Out:
# Scraping completed - '01-08-2008 to 01-08-2010'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

# Function to generate date range from start to end
def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

# Function to extract article URLs, titles, and content from each page
def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

# Generate a range of dates to scrape (change the start and end date as needed)
start_date = "2010-08-02"
end_date = "2012-08-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

# Create a DataFrame from the lists (limit to the first 20 articles)
df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

# Save DataFrame to CSV
df.to_csv('jang_archive_articles_02-08-2010 to 01-08-2012.csv', index=False)
print("Scraping completed - '02-08-2010 to 01-08-2012'")
# Out:
# Scraping completed - '02-08-2010 to 01-08-2012'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

# Function to generate date range from start to end
def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

# Function to extract article URLs, titles, and content from each page
def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

# Generate a range of dates to scrape (change the start and end date as needed)
start_date = "2012-08-02"
end_date = "2014-08-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

# Create a DataFrame from the lists (limit to the first 20 articles)
df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

# Save DataFrame to CSV
df.to_csv('jang_archive_articles_02-08-2012 to 01-08-2014.csv', index=False)
print("Scraping completed - '02-08-2012 to 01-08-2014'")
# Out:
# Scraping completed - '02-08-2012 to 01-08-2014'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

# Function to generate date range from start to end
def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

# Function to extract article URLs, titles, and content from each page
def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

# Generate a range of dates to scrape (change the start and end date as needed)
start_date = "2014-08-02"
end_date = "2016-08-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

# Create a DataFrame from the lists (limit to the first 20 articles)
df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

# Save DataFrame to CSV
df.to_csv('jang_archive_articles_02-08-2014 to 01-08-2016.csv', index=False)
print("Scraping completed - '02-08-2014 to 01-08-2016'")
# Out:
# Scraping completed - '02-08-2014 to 01-08-2016'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

# Function to generate date range from start to end
def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

# Function to extract article URLs, titles, and content from each page
def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

# Generate a range of dates to scrape (change the start and end date as needed)
start_date = "2023-08-02"
end_date = "2024-09-20"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

# Create a DataFrame from the lists (limit to the first 20 articles)
df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

# Save DataFrame to CSV
df.to_csv('jang_archive_articles_02-08-2023 to 20-09-2024.csv', index=False)
print("Scraping completed - '02-08-2023 to 20-09-2024'")
# Out:
# Scraping completed - '02-08-2023 to 20-09-2024'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

# Function to generate date range from start to end
def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

# Function to extract article URLs, titles, and content from each page
def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

# Generate a range of dates to scrape (change the start and end date as needed)
start_date = "2022-08-02"
end_date = "2023-02-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

# Create a DataFrame from the lists (limit to the first 20 articles)
df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

# Save DataFrame to CSV
df.to_csv('jang_archive_02-08-2022 to 01-02-2023.csv', index=False)
print("Scraping completed - '02-08-2022 to 01-02-2023'")
# Out:
# Scraping completed - '02-08-2022 to 01-02-2023'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

# Function to generate date range from start to end
def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

# Function to extract article URLs, titles, and content from each page
def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

# Generate a range of dates to scrape (change the start and end date as needed)
start_date = "2022-02-02"
end_date = "2022-08-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

# Create a DataFrame from the lists (limit to the first 20 articles)
df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

# Save DataFrame to CSV
df.to_csv('jang_archive_02-02-2022 to 01-08-2022.csv', index=False)
print("Scraping completed - '02-02-2022 to 01-08-2022'")
# Out:
# Scraping completed - '02-02-2022 to 01-08-2022'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

start_date = "2017-08-02"
end_date = "2018-02-01"

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

df.to_csv('jang_archive_articles_02-08-2017 to 01-02-2018.csv', index=False)
print("Scraping completed")
# Out:
# Scraping completed - '02-08-2017 to 01-02-2018'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

start_date = "2023-02-02"
end_date = "2023-08-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

df.to_csv('jang_archive_02-02-2023 to 01-08-2023.csv', index=False)
print("Scraping completed - '02-02-2023 to 01-08-2023'")
# Out:
# Scraping completed - '02-02-2023 to 01-08-2023'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

start_date = "2021-08-02"
end_date = "2022-02-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

df.to_csv('jang_archive_02-08-2021 to 01-02-2022.csv', index=False)
print("Scraping completed - '02-08-2021 to 01-02-2022'")
# Out:
# Scraping completed - '02-08-2021 to 01-02-2022'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

start_date = "2021-02-02"
end_date = "2021-08-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

df.to_csv('jang_archive_articles_02-02-2021 to 01-08-2021.csv', index=False)
print("Scraping completed")
# Out:
# Scraping completed

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

start_date = "2018-02-02"
end_date = "2018-08-01"

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

df.to_csv('jang_archive_articles_02-02-2018 to 01-08-2018.csv', index=False)
print("Scraping completed")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

start_date = "2019-08-02"
end_date = "2020-02-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

df.to_csv('jang_archive_articles_02-08-2019 to 01-02-2020.csv', index=False)
print("Scraping completed - '02-08-2019 to 01-08-2020'")
# Out:
# Scraping completed - '02-08-2019 to 01-08-2020'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

start_date = "2019-02-02"
end_date = "2019-08-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

df.to_csv('jang_archive_articles_02-02-2019 to 01-08-2019.csv', index=False)
print("Scraping completed - '02-08-2018 to 01-08-2019'")
# Out:
# Scraping completed - '02-08-2018 to 01-08-2019'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

start_date = "2018-08-02"
end_date = "2019-02-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

df.to_csv('jang_archive_articles_02-08-2018 to 01-02-2019.csv', index=False)
print("Scraping completed - '02-08-2018 to 01-02-2019'")
# Out:
# Scraping completed - '02-08-2018 to 01-02-2019'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

start_date = "2016-08-02"
end_date = "2017-08-01"

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

df.to_csv('jang_archive_articles_02-08-2016 to 01-08-2017.csv', index=False)
print("Scraping completed - '02-08-2016 to 01-08-2017'")
# Out:
# Scraping completed - '02-08-2016 to 01-08-2017'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

start_date = "2020-02-02"
end_date = "2020-08-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

df.to_csv('jang_archive_articles_02-02-2020 to 01-08-2020.csv', index=False)
print("Scraping completed")
# Out:
# Scraping completed

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from datetime import datetime, timedelta

def generate_dates(start_date, end_date):
    start = datetime.strptime(start_date, "%Y-%m-%d")
    end = datetime.strptime(end_date, "%Y-%m-%d")
    delta = timedelta(days=1)
    while start <= end:
        yield start.strftime("%Y-%m-%d")
        start += delta

def scrape_articles(date):
    base_url = f'https://jang.com.pk/category/today-newspaper-archive/{date}'
    response = requests.get(base_url)
    soup = BeautifulSoup(response.text, 'html.parser')

    titles = []
    urls = []
    contents = []

    ul_tags = soup.find_all('ul', {"class": "today_editorial"})

    for ul_tag in ul_tags:
        for li_tag in ul_tag.find_all('li'):
            a_tag = li_tag.find('a', href=True)
            if a_tag:
                article_url = a_tag['href']

                # Fetch the article content
                article_response = requests.get(article_url)
                article_soup = BeautifulSoup(article_response.text, 'html.parser')

                # Extract the title
                title_tag = article_soup.find('h1', {'class': 'detail-right-top'})
                title = title_tag.get_text(strip=True) if title_tag else 'No title found'

                # Extract the content
                content_div = article_soup.find('div', {'class': 'detail_view_content'})
                content = ''
                if content_div:
                    content = content_div.get_text(strip=True)

                titles.append(title)
                urls.append(article_url)
                contents.append(content)

    return titles, urls, contents

start_date = "2020-08-02"
end_date = "2021-02-01"  # You can modify this to limit the range

all_titles = []
all_urls = []
all_contents = []

for date in generate_dates(start_date, end_date):
    titles, urls, contents = scrape_articles(date)
    all_titles.extend(titles)
    all_urls.extend(urls)
    all_contents.extend(contents)

df = pd.DataFrame({
    'Title': all_titles,
    'URL': all_urls,
    'Content': all_contents
})

df.to_csv('jang_archive_articles_02-08-2020 to 01-02-2021.csv', index=False)
print("Scraping completed")
# Out:
# Scraping completed
